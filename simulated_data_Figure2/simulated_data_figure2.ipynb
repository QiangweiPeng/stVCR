# %%
import sys
sys.path.append("..")

# %%
import plot_paper_figure_sim_utils
import importlib
importlib.reload(plot_paper_figure_sim_utils)
# Out:
# 2024-08-17 02:47:41.864051: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# /home/pqw/anaconda3/envs/spatial/lib/python3.8/site-packages/ot/backend.py:2998: UserWarning: To use TensorflowBackend, you need to activate the tensorflow numpy API. You can activate it by running:
# from tensorflow.python.ops.numpy_ops import np_config
# np_config.enable_numpy_behavior()
#   register_backend(TensorflowBackend())
# <module 'plot_paper_figure_sim_utils' from '/home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py'>

# %%
# from plot_paper_figure_sim_utils import plot_sim_obs_data,plot_scatter_growth_com, plot_scatter_vx_com, \
#     plot_scatter_growth, plot_sim_pre_data, plot_ground_truth, plot_true_and_learned_dynamics_gif
import plot_paper_figure_sim_utils
import anndata as ad
from utils import seed_all

# %%
seed_all(123456789)

# %% [markdown]
# ## load data

# %%
adata = ad.read_h5ad('../data/sim5.h5ad')

# %%
sim5_all_exp_path='../data/sim5_all_exp.pkl'
sim5_all_spa_path='../data/sim5_all_spa.pkl'
sim5_all_time_path='../data/sim5_all_time.pkl'

# %%
model_path = '../model_result/model_sim5_1.pth'
rigid_transformation_path = '../model_result/rigid_sim5_1.pth'

# %%
figsize = (6,6)
save_path = None 
s=50

# %% [markdown]
# ## Plot observed data

# %%
plot_paper_figure_sim_utils.plot_sim_obs_data(adata.copy(), spatial_key='spatial', gene_expression_key='X_input', 
                                              figsize = figsize, s=s, save_path=save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:129: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(adata[adata.obs.time == integral_time[i], :].obsm[spatial_key][:, -2],

# %% [markdown]
# ## Plot the comparison of stVCR with real dynamics

# %%
plot_paper_figure_sim_utils.plot_true_and_learned_dynamics_gif(adata.copy(), sim5_all_exp_path, sim5_all_spa_path, sim5_all_time_path, model_path,
                                  save_path = 'true_learn_dynamics.gif')
# Out:
# /home/pqw/spaot/sim_figure2_results/../model.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t = torch.tensor(t).repeat(batchsize).reshape(batchsize, 1)
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:190: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   new_cell = torch.tensor(x[i, :])
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:199: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell = torch.tensor(cur_cell, dtype=torch.float32)
# ...

# %% [markdown]
# ## Plot fit results

# %%
pre_time = 0.5
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=0, 
                                              s=s, figsize =figsize, save_path=save_path)

pre_time = 1.0
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=0,
                                              s=s, figsize =figsize, save_path=save_path)
pre_time = 1.5
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=0,
                                              s=s, figsize =figsize, save_path=save_path)
pre_time = 2.0
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=0,
                                              s=s, figsize =figsize, save_path=save_path)
pre_time = 2.5
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=0,
                                              s=s, figsize =figsize, save_path=save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/../model.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t = torch.tensor(t).repeat(batchsize).reshape(batchsize, 1)
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:190: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   new_cell = torch.tensor(x[i, :])
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:199: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell = torch.tensor(cur_cell, dtype=torch.float32)
# ...

# %% [markdown]
# ## Plot ground truth at the observed time point

# %%
plot_time_list = [0.25, 0.75, 1.25, 1.75, 2.25, 2.75]
plot_paper_figure_sim_utils.plot_ground_truth(adata.copy(), sim5_all_exp_path, sim5_all_spa_path, 
                                              sim5_all_time_path, plot_time_list, s=s, figsize=figsize, save_path=save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:302: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(cur_spa[:, -2],cur_spa[:, -1], vmin=0, vmax=1, c=color, alpha=0.5, edgecolor='black',linewidth=0.2, s=s)

# %% [markdown]
# ## Plot interpolation results

# %%
init_time_point=0
pre_time = 0.25
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=init_time_point,
                  s=s, figsize=figsize, save_path = save_path)

init_time_point=1
pre_time = 0.75
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=init_time_point,
                  s=s, figsize=figsize, save_path = save_path)

init_time_point=2
pre_time = 1.25
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=init_time_point,
                  s=s, figsize=figsize, save_path = save_path)

init_time_point=3
pre_time = 1.75
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=init_time_point,
                  s=s, figsize=figsize, save_path = save_path)

init_time_point=4
pre_time = 2.25
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=init_time_point,
                  s=s, figsize=figsize, save_path = save_path)

init_time_point=5
pre_time = 2.75
plot_paper_figure_sim_utils.plot_sim_pre_data(adata.copy(), pre_time=pre_time, model_path=model_path, rigid_transformation_path=rigid_transformation_path,
                  spatial_key='spatial', gene_expression_key='X_input', init_time_point=init_time_point,
                  s=s, figsize=figsize, save_path = save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/../model.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t = torch.tensor(t).repeat(batchsize).reshape(batchsize, 1)
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:199: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell = torch.tensor(cur_cell, dtype=torch.float32)
# /home/pqw/spaot/sim_figure2_results/../model.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t = torch.tensor(t).repeat(batchsize).reshape(batchsize, 1)
# ...

# %% [markdown]
# ## Plot growth rate

# %%
spatial_key = 'spatial'
time_point = 5
plot_paper_figure_sim_utils.plot_scatter_growth(adata.copy(), model_path, rigid_transformation_path, spatial_key, 
                                                time_point, truth=False, s=s, figsize=figsize, save_path=save_path)
plot_paper_figure_sim_utils.plot_scatter_growth(adata.copy(), model_path, rigid_transformation_path, spatial_key, 
                                                time_point, truth=True, s=s, figsize=figsize, save_path=save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:405: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell_learn = torch.tensor(data_train[train_time[time_point]], requires_grad=False)
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:406: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell_truth = torch.tensor(data_train[train_time[time_point]], requires_grad=False)
# /home/pqw/spaot/sim_figure2_results/../model.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...

# %% [markdown]
# ## Plot regulatory relationships

# %%
source_number = 3
spatial_key = 'spatial'
time_point = 5
plot_paper_figure_sim_utils.plot_scatter_growth_com(adata.copy(), source_number, model_path, rigid_transformation_path, 
                                                    spatial_key, time_point, truth=False,
                                                   s=s, figsize=figsize,save_path=save_path)
plot_paper_figure_sim_utils.plot_scatter_growth_com(adata.copy(), source_number, model_path, rigid_transformation_path, 
                                                    spatial_key, time_point, truth=True,
                                                   s=s, figsize=figsize,save_path=save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:328: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell_learn = torch.tensor(data_train[train_time[time_point]], requires_grad=True)
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:329: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell_truth = torch.tensor(data_train[train_time[time_point]], requires_grad=True)
# /home/pqw/spaot/sim_figure2_results/../model.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...

# %%
source_number = 0
target_number = 1
spatial_key = 'spatial'
time_point = 5
plot_paper_figure_sim_utils.plot_scatter_vx_com(adata.copy(), target_number, source_number, model_path, rigid_transformation_path, spatial_key, 
                    time_point, truth=False, s=s, figsize=figsize, save_path=save_path)
plot_paper_figure_sim_utils.plot_scatter_vx_com(adata.copy(), target_number, source_number, model_path, rigid_transformation_path, spatial_key, 
                    time_point, truth=True, s=s, figsize=figsize, save_path=save_path)
# Out:
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:482: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell_learn = torch.tensor(data_train[train_time[time_point]], requires_grad=True)
# /home/pqw/spaot/sim_figure2_results/plot_paper_figure_sim_utils.py:483: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_cell_truth = torch.tensor(data_train[train_time[time_point]], requires_grad=True)
# /home/pqw/spaot/sim_figure2_results/../model.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...
